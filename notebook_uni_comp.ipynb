# %% [markdown]
# ## step 1: imports

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### load the dataset into a dataframe

# %%
companies = pd.read_csv("Unicorn_Companies.csv")

# %%
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B      4/7/17          Artificial intelligence
# 1     SpaceX     $100B     12/1/12                            Other
# 2      SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3     Stripe      $95B     1/23/14                          Fintech
# 4     Klarna      $46B    12/12/11                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %% [markdown]
# ## step 2: data exploration

# %%
# the first 10 rows of the data.

companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
# the number of rows and columns in the dataset

companies.shape
# Out:
# (1074, 10)

# %% [markdown]
# ###### 1074 rows and 10 columns

# %% [markdown]
# #### check for duplicates in the data

# %%
# I will do this by checking the shape again after deleting the duplicates using 'drop_duplicates' method.

companies.drop_duplicates().shape
# Out:
# (1074, 10)

# %% [markdown]
# ###### still the same so there are no duplicates.

# %% [markdown]
# #### display the data types of the columns

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
# or
companies.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country/Region      object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %% [markdown]
# #### sort the data

# %%
companies.sort_values("Year Founded", ascending=False)
# Out:
#                         Company Valuation Date Joined  \
# 782                     Phantom       $1B     1/31/22
# 714                Yidian Zixun       $1B    10/17/17
# 822                  GlobalBees       $1B    12/28/21
# 554                  ClickHouse       $2B    10/28/21
# 952              LayerZero Labs       $1B     3/30/22
# ..                          ...       ...         ...
# 11                   Epic Games      $32B    10/26/18
# 840    Radius Payment Solutions       $1B    11/27/17
# 699  Five Star Business Finance       $1B     3/26/21
# 373         Promasidor Holdings       $2B     11/8/16
# 189        Otto Bock HealthCare       $4B     6/24/17
#
#                             Industry            City  Country/Region  \
# 782                          Fintech   San Francisco   United States
# 714      Mobile & telecommunications         Beijing           China
# 822  E-commerce & direct-to-consumer       New Delhi           India
# ...

# %% [markdown]
# #### determine the number of companies founded each year

# %%
companies.value_counts("Year Founded").sort_values(ascending=True)
# Out:
# Year Founded
# 1919      1
# 1979      1
# 1997      1
# 1996      1
# 1984      1
# 1992      1
# 1991      1
# 1990      1
# 1993      1
# 1995      2
# 1994      2
# 2002      4
# 1998      5
# 1999      8
# 2003      8
# 2004      8
# 2001      9
# 2021     11
# 2000     11
# 2005     14
# 2006     15
# 2007     24
# 2020     25
# 2008     27
# 2009     34
# 2010     40
# 2019     45
# 2018     61
# 2017     74
# 2011     82
# 2013     87
# 2012     95
# 2014    109
# 2016    110
# 2015    155
# Name: count, dtype: int64

# %%
sns.histplot(data=companies, x='Year Founded')
plt.title('Year Founded histogram');

# %% [markdown]
# #### convert the `Date Joined` column to datetime

# %%
companies["Date Joined"] = pd.to_datetime(companies["Date Joined"])

companies.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country/Region              object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %% [markdown]
# #### creating a `Month Joined` column

# %%
companies['Month Joined'] = companies["Date Joined"].dt.month_name()
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors Month Joined  \
# 0  Sequoia Capital China, SIG Asia Investments, S...        April
# ...

# %% [markdown]
# #### creating a `Years To Join` column

# %%
companies['Years To Join'] = companies["Date Joined"].dt.year - companies["Year Founded"]
companies.head(30)
# Out:
#            Company Valuation Date Joined                             Industry  \
# 0        Bytedance     $180B  2017-04-07              Artificial intelligence
# 1           SpaceX     $100B  2012-12-01                                Other
# 2            SHEIN     $100B  2018-07-03      E-commerce & direct-to-consumer
# 3           Stripe      $95B  2014-01-23                              Fintech
# 4           Klarna      $46B  2011-12-12                              Fintech
# 5            Canva      $40B  2018-01-08         Internet software & services
# 6     Checkout.com      $40B  2019-05-02                              Fintech
# 7        Instacart      $39B  2014-12-30  Supply chain, logistics, & delivery
# 8        JUUL Labs      $38B  2017-12-20                    Consumer & retail
# 9       Databricks      $38B  2019-02-05          Data management & analytics
# 10         Revolut      $33B  2018-04-26                              Fintech
# ...

# %% [markdown]
# #### gain more insight on a specific year

# %%
companies_joined_2021 = companies[companies["Date Joined"].dt.year == 2021].copy()

companies_joined_2021.head()
# Out:
#            Company Valuation Date Joined                             Industry  \
# 12             FTX      $32B  2021-07-20                              Fintech
# 16     J&T Express      $20B  2021-04-07  Supply chain, logistics, & delivery
# 24  Blockchain.com      $14B  2021-02-17                              Fintech
# 27         OpenSea      $13B  2021-07-20      E-commerce & direct-to-consumer
# 34           Getir      $12B  2021-03-26      E-commerce & direct-to-consumer
#
#         City  Country/Region      Continent  Year Founded Funding  \
# 12       NaN         Bahamas  North America          2018     $2B
# 16   Jakarta       Indonesia           Asia          2015     $5B
# 24    London  United Kingdom         Europe          2011   $490M
# 27  New York   United States  North America          2017   $427M
# 34  Istanbul          Turkey         Europe          2015     $2B
#
#                                      Select Investors Month Joined  \
# ...

# %%
companies_joined_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520 entries, 12 to 1072
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           520 non-null    object
#  1   Valuation         520 non-null    object
#  2   Date Joined       520 non-null    datetime64[ns]
#  3   Industry          520 non-null    object
#  4   City              507 non-null    object
#  5   Country/Region    520 non-null    object
#  6   Continent         520 non-null    object
#  7   Year Founded      520 non-null    int64
#  8   Funding           520 non-null    object
#  9   Select Investors  520 non-null    object
#  10  Month Joined      520 non-null    object
#  11  Years To Join     520 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 52.8+ KB

# %% [markdown]
# #### observing trends over time

# %%
companies_joined_2021["Quarter Joined"] = companies_joined_2021["Date Joined"].dt.quarter

# %%
companies_joined_2021.head()
# Out:
#            Company Valuation Date Joined                             Industry  \
# 12             FTX      $32B  2021-07-20                              Fintech
# 16     J&T Express      $20B  2021-04-07  Supply chain, logistics, & delivery
# 24  Blockchain.com      $14B  2021-02-17                              Fintech
# 27         OpenSea      $13B  2021-07-20      E-commerce & direct-to-consumer
# 34           Getir      $12B  2021-03-26      E-commerce & direct-to-consumer
#
#         City  Country/Region      Continent  Year Founded Funding  \
# 12       NaN         Bahamas  North America          2018     $2B
# 16   Jakarta       Indonesia           Asia          2015     $5B
# 24    London  United Kingdom         Europe          2011   $490M
# 27  New York   United States  North America          2017   $427M
# 34  Istanbul          Turkey         Europe          2015     $2B
#
#                                      Select Investors Month Joined  \
# ...

# %%
companies_joined_2021["Quarter Joined"] = companies_joined_2021["Date Joined"].dt.to_period("Q").dt.strftime("Q%q")

# %%
companies_joined_2021.head()
# Out:
#            Company Valuation Date Joined                             Industry  \
# 12             FTX      $32B  2021-07-20                              Fintech
# 16     J&T Express      $20B  2021-04-07  Supply chain, logistics, & delivery
# 24  Blockchain.com      $14B  2021-02-17                              Fintech
# 27         OpenSea      $13B  2021-07-20      E-commerce & direct-to-consumer
# 34           Getir      $12B  2021-03-26      E-commerce & direct-to-consumer
#
#         City  Country/Region      Continent  Year Founded Funding  \
# 12       NaN         Bahamas  North America          2018     $2B
# 16   Jakarta       Indonesia           Asia          2015     $5B
# 24    London  United Kingdom         Europe          2011   $490M
# 27  New York   United States  North America          2017   $427M
# 34  Istanbul          Turkey         Europe          2015     $2B
#
#                                      Select Investors Month Joined  \
# ...

# %%
companies_by_quarter_2021= companies_joined_2021.groupby("Quarter Joined").agg(
    quarter_count = pd.NamedAgg(column="Quarter Joined", aggfunc="count"),
)
companies_by_quarter_2021.head()
# Out:
#                 quarter_count
# Quarter Joined
# Q1                        108
# Q2                        144
# Q3                        134
# Q4                        134

# %%
companies_joined_2021.insert(3, "Week Joined", companies_joined_2021["Date Joined"].dt.strftime('%Y-W%V'), True)

companies_by_week_2021 = companies_joined_2021.groupby(by="Week Joined")["Company"].count().reset_index().rename(columns={"Company":"Company Count"})

companies_by_week_2021.head()
# Out:
#   Week Joined  Company Count
# 0    2021-W01             12
# 1    2021-W02              9
# 2    2021-W03              5
# 3    2021-W04              8
# 4    2021-W05              4

# %%
companies_joined_2020 = companies[companies["Date Joined"].dt.year == 2020].copy()

companies_joined_2020.insert(3, "Week Joined", companies_joined_2020["Date Joined"].dt.strftime('%Y-W%V'), True)

companies_by_week_2020 = companies_joined_2020.groupby(by="Week Joined")["Company"].count().reset_index().rename(
    columns={"Company": "Company Count"})

companies_by_week_2020
# Out:
#    Week Joined  Company Count
# 0     2020-W01              1
# 1     2020-W02              2
# 2     2020-W04              4
# 3     2020-W05              3
# 4     2020-W06              1
# 5     2020-W07              2
# 6     2020-W09              1
# 7     2020-W10              1
# 8     2020-W11              1
# 9     2020-W12              1
# 10    2020-W14              2
# 11    2020-W15              1
# 12    2020-W16              1
# 13    2020-W18              3
# 14    2020-W19              1
# 15    2020-W20              1
# 16    2020-W21              2
# 17    2020-W22              2
# 18    2020-W24              2
# 19    2020-W25              2
# 20    2020-W26              1
# 21    2020-W27              2
# 22    2020-W28              1
# 23    2020-W29              3
# 24    2020-W30              1
# 25    2020-W31              3
# 26    2020-W32              2
# 27    2020-W33              2
# 28    2020-W34              2
# 29    2020-W35              2
# ...

# %%
companies_by_week_20_21= pd.concat([companies_by_week_2021, companies_by_week_2020], axis=0, ignore_index=True)

# %%
companies_by_week_20_21["Week Number"] = companies_by_week_20_21["Week Joined"].str[-2:]

# %%
companies_by_week_20_21.head()
# Out:
#   Week Joined  Company Count Week Number
# 0    2021-W01             12          01
# 1    2021-W02              9          02
# 2    2021-W03              5          03
# 3    2021-W04              8          04
# 4    2021-W05              4          05

# %% [markdown]
# #### comparing trends over time

# %%
companies_2020_2021 = pd.concat([companies_joined_2020, companies_joined_2021.drop(columns=['Week Joined', 'Quarter Joined'])])

# %%
companies_2020_2021.head()
# Out:
#                Company Valuation Date Joined Week Joined  \
# 22        Genki Forest      $15B  2020-03-01    2020-W09
# 23              goPuff      $15B  2020-10-08    2020-W41
# 38  Xingsheng Selected      $12B  2020-07-22    2020-W30
# 54               Figma      $10B  2020-04-30    2020-W18
# 57         Notion Labs      $10B  2020-04-01    2020-W14
#
#                            Industry           City Country/Region  \
# 22                Consumer & retail        Beijing          China
# 23  E-commerce & direct-to-consumer   Philadelphia  United States
# 38  E-commerce & direct-to-consumer       Changsha          China
# 54     Internet software & services  San Francisco  United States
# 57     Internet software & services  San Francisco  United States
#
#         Continent  Year Founded Funding  \
# 22           Asia          2016   $721M
# 23  North America          2013     $3B
# 38           Asia          2009     $5B
# 54  North America          2012   $333M
# ...

# %%
companies_2020_2021["Quarter Joined"] = companies_2020_2021["Date Joined"].dt.to_period('Q').dt.strftime('%Y-Q%q')

# %%
companies_2020_2021.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Week Joined', 'Industry',
#        'City', 'Country/Region', 'Continent', 'Year Founded', 'Funding',
#        'Select Investors', 'Month Joined', 'Years To Join', 'Quarter Joined'],
#       dtype='object')

# %%
companies_2020_2021["Valuation"] = companies_2020_2021["Valuation"].str.strip("$B").astype(float)

# %%
companies_2020_2021["Valuation"].head()
# Out:
# 22    15.0
# 23    15.0
# 38    12.0
# 54    10.0
# 57    10.0
# Name: Valuation, dtype: float64

# %%
companies_by_quarter_2020_2021 = companies_2020_2021.groupby(by="Quarter Joined")["Valuation"].mean().reset_index().rename(columns={"Valuation":"Average Valuation"})
companies_by_quarter_2020_2021.head()
# Out:
#   Quarter Joined  Average Valuation
# 0        2020-Q1           3.444444
# 1        2020-Q2           3.777778
# 2        2020-Q3           3.896552
# 3        2020-Q4           3.697674
# 4        2021-Q1           2.750000
