# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./eda_using_basic_data_functions_in_python_dataset1.csv")
df.head(10)
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)
# 5  2018-01-03                119     POINT(-78 28)
# 6  2018-01-03                 35   POINT(-79.3 28)
# 7  2018-01-03                 60   POINT(-79.1 28)
# 8  2018-01-03                 41   POINT(-78.7 28)
# 9  2018-01-03                119   POINT(-78.6 28)

# %%
df["date"] = pd.to_datetime(df["date"])
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)
# 5 2018-01-03                119     POINT(-78 28)
# 6 2018-01-03                 35   POINT(-79.3 28)
# 7 2018-01-03                 60   POINT(-79.1 28)
# 8 2018-01-03                 41   POINT(-78.7 28)
# 9 2018-01-03                119   POINT(-78.6 28)

# %%
df.shape
# Out:
# (3401012, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401012 entries, 0 to 3401011
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   date               datetime64[ns]
#  1   number_of_strikes  int64
#  2   center_point_geom  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 77.8+ MB

# %%
df['date']= pd.to_datetime(df['date'])

# %%
# Calculate days with most lightning strikes.
df.groupby(['date']).sum().sort_values('number_of_strikes', ascending=False).head(10)
# Out:
#             number_of_strikes  \
# date
# 2018-08-29            1070457
# 2018-08-17             969774
# 2018-08-28             917199
# 2018-08-27             824589
# 2018-08-30             802170
# 2018-08-19             786225
# 2018-08-18             741180
# 2018-08-16             734475
# 2018-08-31             723624
# 2018-08-15             673455
#
#                                             center_point_geom
# date
# 2018-08-29  POINT(-85.7 29.1)POINT(-85.6 29.1)POINT(-84.5 ...
# 2018-08-17  POINT(-80.6 20.3)POINT(-80.5 20.3)POINT(-80.4 ...
# 2018-08-28  POINT(-108.2 28)POINT(-108.1 28)POINT(-108 28)...
# 2018-08-27  POINT(-109 24.8)POINT(-108 24.8)POINT(-88.1 24...
# 2018-08-30  POINT(-75.7 19)POINT(-75.6 19)POINT(-78 20)POI...
# 2018-08-19  POINT(-73 35)POINT(-103 35)POINT(-101 35)POINT...
# 2018-08-18  POINT(-110.7 46)POINT(-104.9 46)POINT(-115.1 4...
# 2018-08-16  POINT(-97 20)POINT(-77 20)POINT(-96.9 20)POINT...
# ...

# %%
df["month"] = df["date"].dt.month
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom  month month_txt
# 0 2018-01-03                194     POINT(-75 27)      1       Jan
# 1 2018-01-03                 41   POINT(-78.4 29)      1       Jan
# 2 2018-01-03                 33   POINT(-73.9 27)      1       Jan
# 3 2018-01-03                 38   POINT(-73.8 27)      1       Jan
# 4 2018-01-03                 92     POINT(-79 28)      1       Jan
# 5 2018-01-03                119     POINT(-78 28)      1       Jan
# 6 2018-01-03                 35   POINT(-79.3 28)      1       Jan
# 7 2018-01-03                 60   POINT(-79.1 28)      1       Jan
# 8 2018-01-03                 41   POINT(-78.7 28)      1       Jan
# 9 2018-01-03                119   POINT(-78.6 28)      1       Jan

# %%
# Calculate total number of strikes per month
df.groupby(['month']).sum(numeric_only=True).sort_values('number_of_strikes', ascending=False).head(12)
# Out:
#        number_of_strikes
# month
# 8               15525255
# 7                8320400
# 6                6445083
# 5                4166726
# 9                3018336
# 2                2071315
# 4                1524339
# 10               1093962
# 1                 860045
# 3                 854168
# 11                409263
# 12                312097

# %%
# Calculate total number of strikes per month
df.groupby(['month'])[['number_of_strikes']].sum().sort_values('number_of_strikes', ascending=False).head(12)
# Out:
#        number_of_strikes
# month
# 8               15525255
# 7                8320400
# 6                6445083
# 5                4166726
# 9                3018336
# 2                2071315
# 4                1524339
# 10               1093962
# 1                 860045
# 3                 854168
# 11                409263
# 12                312097

# %%
df["month_txt"] = df["date"].dt.month_name().str.slice(stop=3)
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom  month month_txt
# 0 2018-01-03                194     POINT(-75 27)      1       Jan
# 1 2018-01-03                 41   POINT(-78.4 29)      1       Jan
# 2 2018-01-03                 33   POINT(-73.9 27)      1       Jan
# 3 2018-01-03                 38   POINT(-73.8 27)      1       Jan
# 4 2018-01-03                 92     POINT(-79 28)      1       Jan
# 5 2018-01-03                119     POINT(-78 28)      1       Jan
# 6 2018-01-03                 35   POINT(-79.3 28)      1       Jan
# 7 2018-01-03                 60   POINT(-79.1 28)      1       Jan
# 8 2018-01-03                 41   POINT(-78.7 28)      1       Jan
# 9 2018-01-03                119   POINT(-78.6 28)      1       Jan

# %%
df_by_month = df.groupby(["month", "month_txt"])[["number_of_strikes"]].sum().sort_values(by=["month"], ascending=True).head(12).reset_index()
df_by_month.head(10)
# Out:
#    month month_txt  number_of_strikes
# 0      1       Jan             860045
# 1      2       Feb            2071315
# 2      3       Mar             854168
# 3      4       Apr            1524339
# 4      5       May            4166726
# 5      6       Jun            6445083
# 6      7       Jul            8320400
# 7      8       Aug           15525255
# 8      9       Sep            3018336
# 9     10       Oct            1093962

# %%
df_by_month = df.groupby(["month", "month_txt"]).sum(numeric_only=True).sort_values(by=["month"], ascending=True).head(12).reset_index()
df_by_month.head(10)
# Out:
#    month month_txt  number_of_strikes
# 0      1       Jan             860045
# 1      2       Feb            2071315
# 2      3       Mar             854168
# 3      4       Apr            1524339
# 4      5       May            4166726
# 5      6       Jun            6445083
# 6      7       Jul            8320400
# 7      8       Aug           15525255
# 8      9       Sep            3018336
# 9     10       Oct            1093962

# %%
plt.bar(x=df_by_month['month_txt'], height= df_by_month['number_of_strikes'], label="Number of strikes")
plt.plot()

plt.xlabel("Months(2018)")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes in 2018 by months")
plt.legend()
plt.show()

# %%
companies = pd.read_csv("Unicorn_Companies.csv")

# %%
companies.sort_values("Valuation").head(10)
# Out:
#                    Company Valuation Date Joined  \
# 1                   SpaceX     $100B     12/1/12
# 2                    SHEIN     $100B      7/3/18
# 51                 Alchemy      $10B    10/28/21
# 46               Zuoyebang      $10B     7/18/18
# 47                  Ripple      $10B    12/20/19
# 48               OYO Rooms      $10B     9/25/18
# 49              OutSystems      $10B      6/5/18
# 50            ServiceTitan      $10B    11/14/18
# 52               Chehaoduo      $10B     3/12/16
# 53  Digital Currency Group      $10B     11/1/21
#
#                            Industry           City Country/Region  \
# 1                             Other      Hawthorne  United States
# 2   E-commerce & direct-to-consumer       Shenzhen          China
# 51                          Fintech  San Francisco  United States
# 46                           Edtech        Beijing          China
# 47                          Fintech  San Francisco  United States
# ...

# %%
companies.size
# Out:
# 10740

# %%
companies.shape
# Out:
# (1074, 10)

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
companies.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %%
companies["Date Joined"] = pd.to_datetime(companies["Date Joined"], format="mixed", dayfirst=True)

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %%
companies["Year Joined"] = companies["Date Joined"].dt.year

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
#  10  Year Joined       1074 non-null   int32
# dtypes: datetime64[ns](1), int32(1), int64(1), object(8)
# memory usage: 88.2+ KB

# %%
companies["Year Joined"].head(10)
# Out:
# 0    2017
# 1    2012
# 2    2018
# 3    2014
# 4    2011
# 5    2018
# 6    2019
# 7    2014
# 8    2017
# 9    2019
# Name: Year Joined, dtype: int32

# %%
companies_sampled = companies.sample(random_state=5,n=50)

# %%
companies_sampled
# Out:
#                          Company Valuation Date Joined  \
# 917                Flash Express       $1B  2021-01-02
# 846                    Instabase       $1B  2019-10-21
# 995                      Payhawk       $1B  2022-02-14
# 562                       Exotec       $2B  2022-01-17
# 477                      Harness       $2B  2021-01-14
# 895                   Clearcover       $1B  2021-04-13
# 60                       Thrasio      $10B  2020-07-15
# 682                       Coocaa       $1B  2018-03-16
# 352                    Traveloka       $3B  2017-01-01
# 458                     Zhubajie       $2B  2015-06-16
# 72               DJI Innovations       $8B  2015-01-23
# 681                         Aleo       $1B  2022-07-02
# 283                    OwnBackup       $3B  2021-01-28
# 1071                    Zihaiguo       $1B  2021-06-05
# 246                        Yixia       $3B  2015-11-24
# 1067                   YipitData       $1B  2021-06-12
# ...

# %%
companies_sampled["time_took"] = companies_sampled["Year Joined"] - companies_sampled["Year Founded"]
companies_by_time = companies_sampled[["Industry", "time_took"]].groupby(["Industry"]).max().sort_values(by=["time_took"], ascending=True)
companies_by_time
# Out:
#                                      time_took
# Industry
# Artificial Intelligence                      2
# Cybersecurity                                3
# Supply chain, logistics, & delivery          4
# Artificial intelligence                      5
# Auto & transportation                        5
# Edtech                                       5
# Travel                                       5
# Health                                      10
# Hardware                                    12
# Consumer & retail                           13
# Mobile & telecommunications                 13
# E-commerce & direct-to-consumer             15
# Internet software & services                17
# Data management & analytics                 22
# Fintech                                     22
# Other                                       27

# %%
plt.bar(x=companies_by_time.index,height= companies_by_time['time_took'])
plt.plot()

plt.xlabel("Industry")
plt.ylabel("Maximum number of years")
plt.title("Number of lightning strikes in 2018 by months")
plt.xticks(rotation=45, horizontalalignment='right')


plt.show()

# %%
date_manipulation_df = pd.read_csv("./eda_manipulate_date_strings_with_python.csv")

# %%
date_manipulation_df.head(10)
# Out:
#          date  number_of_strikes   center_point_geom
# 0  2016-08-05                 16  POINT(-101.5 24.7)
# 1  2016-08-05                 16     POINT(-85 34.3)
# 2  2016-08-05                 16     POINT(-89 41.4)
# 3  2016-08-05                 16   POINT(-89.8 30.7)
# 4  2016-08-05                 16   POINT(-86.2 37.9)
# 5  2016-08-05                 16   POINT(-97.8 38.9)
# 6  2016-08-05                 16     POINT(-81.9 36)
# 7  2016-08-05                 16   POINT(-90.9 36.7)
# 8  2016-08-05                 16  POINT(-106.6 26.1)
# 9  2016-08-05                 16    POINT(-108 31.6)

# %%
date_manipulation_df.shape
# Out:
# (10479003, 3)

# %%
date_manipulation_df["date"] = pd.to_datetime(date_manipulation_df["date"])

# %%
date_manipulation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10479003 entries, 0 to 10479002
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   date               datetime64[ns]
#  1   number_of_strikes  int64
#  2   center_point_geom  object
#  3   week               object
#  4   month              object
#  5   quarter            object
#  6   year               object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 559.6+ MB

# %%
date_manipulation_df["week"] = date_manipulation_df["date"].dt.strftime("%Y-W%W")

date_manipulation_df["month"] = date_manipulation_df["date"].dt.strftime("%Y-%m")

date_manipulation_df["quarter"] = date_manipulation_df["date"].dt.to_period("Q").dt.strftime("%Y-Q%q")

date_manipulation_df['year'] = date_manipulation_df['date'].dt.strftime('%Y')

date_manipulation_df.head(10)
# Out:
#         date  number_of_strikes   center_point_geom      week    month  \
# 0 2016-08-05                 16  POINT(-101.5 24.7)  2016-W31  2016-08
# 1 2016-08-05                 16     POINT(-85 34.3)  2016-W31  2016-08
# 2 2016-08-05                 16     POINT(-89 41.4)  2016-W31  2016-08
# 3 2016-08-05                 16   POINT(-89.8 30.7)  2016-W31  2016-08
# 4 2016-08-05                 16   POINT(-86.2 37.9)  2016-W31  2016-08
# 5 2016-08-05                 16   POINT(-97.8 38.9)  2016-W31  2016-08
# 6 2016-08-05                 16     POINT(-81.9 36)  2016-W31  2016-08
# 7 2016-08-05                 16   POINT(-90.9 36.7)  2016-W31  2016-08
# 8 2016-08-05                 16  POINT(-106.6 26.1)  2016-W31  2016-08
# 9 2016-08-05                 16    POINT(-108 31.6)  2016-W31  2016-08
#
#    quarter  year
# 0  2016-Q3  2016
# 1  2016-Q3  2016
# 2  2016-Q3  2016
# 3  2016-Q3  2016
# 4  2016-Q3  2016
# 5  2016-Q3  2016
# 6  2016-Q3  2016
# 7  2016-Q3  2016
# 8  2016-Q3  2016
# ...

# %%
df_by_week_2018 = date_manipulation_df[date_manipulation_df["year"] == "2018"].groupby(["week"]).sum(numeric_only=True).reset_index()
df_by_week_2018.head(10)
# Out:
#        week  number_of_strikes
# 0  2018-W01              34059
# 1  2018-W02             353425
# 2  2018-W03              37132
# 3  2018-W04             412772
# 4  2018-W05              34972
# 5  2018-W06             568417
# 6  2018-W07              60847
# 7  2018-W08            1347198
# 8  2018-W09              94082
# 9  2018-W10             196358

# %%
plt.bar(x=df_by_week_2018["week"],height= df_by_week_2018["number_of_strikes"])
plt.plot()
plt.xlabel("Week number")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes per week (2018)");

# %%
plt.figure(figsize = (20, 5)) # Increase output size.
plt.bar(x = df_by_week_2018['week'], height = df_by_week_2018['number_of_strikes'])
plt.plot()
plt.xlabel("Week number")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes per week (2018)")
plt.xticks(rotation = 45, fontsize = 8) # Rotate x-axis labels and decrease font size.

plt.show()

# %%
df_by_quarter = date_manipulation_df['number_of_strikes'].div(1000000)
df_by_quarter.head()
# Out:
# 0    0.000016
# 1    0.000016
# 2    0.000016
# 3    0.000016
# 4    0.000016
# Name: number_of_strikes, dtype: float64

# %%
df_by_quarter = date_manipulation_df.groupby(["quarter"])["number_of_strikes"].sum().reset_index()

df_by_quarter['number_of_strikes_formatted'] = df_by_quarter['number_of_strikes'].div(1000000).round(1).astype(str) + 'M'
df_by_quarter.head()
# Out:
#    quarter  number_of_strikes number_of_strikes_formatted
# 0  2016-Q1            2683798                        2.7M
# 1  2016-Q2           15084857                       15.1M
# 2  2016-Q3           21843820                       21.8M
# 3  2016-Q4            1969754                        2.0M
# 4  2017-Q1            2444279                        2.4M

# %%
def addlabels(x, y, labels):
    '''
    Iterates over data and plots text labels above each bar of bar graph.
    '''
    for i in range(len(x)):
        plt.text(i, y[i], labels[i], ha = 'center', va = 'bottom')

# %%
plt.figure(figsize = (15, 5))
plt.bar(x = df_by_quarter['quarter'], height = df_by_quarter['number_of_strikes'])
addlabels(df_by_quarter['quarter'], df_by_quarter['number_of_strikes'], df_by_quarter['number_of_strikes_formatted'])
plt.plot()
plt.xlabel('Quarter')
plt.ylabel('Number of lightning strikes')
plt.title('Number of lightning strikes per quarter (2016-2018)')
plt.show()

# %%
df_by_quarter['quarter_number'] = df_by_quarter['quarter'].str[-2:]
df_by_quarter['year'] = df_by_quarter['quarter'].str[:4]
df_by_quarter.head()
# Out:
#    quarter  number_of_strikes number_of_strikes_formatted quarter_number  year
# 0  2016-Q1            2683798                        2.7M             Q1  2016
# 1  2016-Q2           15084857                       15.1M             Q2  2016
# 2  2016-Q3           21843820                       21.8M             Q3  2016
# 3  2016-Q4            1969754                        2.0M             Q4  2016
# 4  2017-Q1            2444279                        2.4M             Q1  2017

# %%
plt.figure(figsize = (15, 5))
p = sns.barplot(
    data = df_by_quarter,
    x = 'quarter_number',
    y = 'number_of_strikes',
    hue = 'year')
for b in p.patches:
    p.annotate(str(round(b.get_height()/1000000, 1))+'M',
                   (b.get_x() + b.get_width() / 2., b.get_height() + 1.2e6),
                   ha = 'center', va = "bottom",
                   xytext = (0, -12),
                   textcoords = 'offset points')
plt.xlabel("Quarter")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes per quarter (2016-2018)")
plt.show()

# %% [markdown]
# # EDA structuring with Python

# %%
df_structuring= pd.read_csv("./eda_structuring_with_python_dataset1.csv")

# %%
df_structuring.head(10)
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)
# 5  2018-01-03                119     POINT(-78 28)
# 6  2018-01-03                 35   POINT(-79.3 28)
# 7  2018-01-03                 60   POINT(-79.1 28)
# 8  2018-01-03                 41   POINT(-78.7 28)
# 9  2018-01-03                119   POINT(-78.6 28)

# %%
df_structuring["date"] = pd.to_datetime(df_structuring["date"])

# %%
df_structuring.shape
# Out:
# (3401012, 3)

# %%
df_structuring.drop_duplicates().shape
# if the shape of data is different after running this code, it would show that there were duplicate rows.
# Out:
# (3401012, 3)

# %%
df_structuring.sort_values(by=["number_of_strikes"], ascending=False).head(10)
# Out:
#              date  number_of_strikes  center_point_geom
# 302758 2018-08-20               2211  POINT(-92.5 35.5)
# 278383 2018-08-16               2142  POINT(-96.1 36.1)
# 280830 2018-08-17               2061  POINT(-90.2 36.1)
# 280453 2018-08-17               2031  POINT(-89.9 35.9)
# 278382 2018-08-16               1902  POINT(-96.2 36.1)
# 11517  2018-02-10               1899  POINT(-95.5 28.1)
# 277506 2018-08-16               1878  POINT(-89.7 31.5)
# 24906  2018-02-25               1833  POINT(-98.7 28.9)
# 284320 2018-08-17               1767    POINT(-90.1 36)
# 24825  2018-02-25               1741      POINT(-98 29)

# %%
df_structuring["center_point_geom"].value_counts()
# Out:
# center_point_geom
# POINT(-81.5 22.5)     108
# POINT(-84.1 22.4)     108
# POINT(-82.5 22.9)     107
# POINT(-82.7 22.9)     107
# POINT(-82.5 22.8)     106
#                      ...
# POINT(-119.3 35.1)      1
# POINT(-119.3 35)        1
# POINT(-119.6 35.6)      1
# POINT(-119.4 35.6)      1
# POINT(-58.5 45.3)       1
# Name: count, Length: 170855, dtype: int64

# %%
df_structuring["center_point_geom"].value_counts(ascending=True).head(10)
# Out:
# center_point_geom
# POINT(-58.5 45.3)     1
# POINT(-128.6 34.6)    1
# POINT(-126.7 34.5)    1
# POINT(-126.8 34.5)    1
# POINT(-127.7 34.5)    1
# POINT(-128.1 34.5)    1
# POINT(-127 34.5)      1
# POINT(-127.5 34.4)    1
# POINT(-128.2 34.4)    1
# POINT(-126.8 34.3)    1
# Name: count, dtype: int64

# %%
df.center_point_geom.value_counts()[:20].rename_axis('unique_values').reset_index(name='counts').style.background_gradient()
# Out:
# <style type="text/css">
# #T_99d06_row0_col1, #T_99d06_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_99d06_row2_col1, #T_99d06_row3_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_99d06_row4_col1, #T_99d06_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_99d06_row6_col1, #T_99d06_row7_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_99d06_row8_col1, #T_99d06_row9_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_99d06_row10_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_99d06_row11_col1, #T_99d06_row12_col1, #T_99d06_row13_col1, #T_99d06_row14_col1, #T_99d06_row15_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_99d06_row16_col1, #T_99d06_row17_col1, #T_99d06_row18_col1, #T_99d06_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_99d06">
#   <thead>
#     <tr>
# ...

# %%
df_structuring["week"] = df_structuring["date"].dt.isocalendar().week

df_structuring["weekday"] = df_structuring["date"].dt.day_name()

df_structuring.head(10)
# Out:
#         date  number_of_strikes center_point_geom  week    weekday
# 0 2018-01-03                194     POINT(-75 27)     1  Wednesday
# 1 2018-01-03                 41   POINT(-78.4 29)     1  Wednesday
# 2 2018-01-03                 33   POINT(-73.9 27)     1  Wednesday
# 3 2018-01-03                 38   POINT(-73.8 27)     1  Wednesday
# 4 2018-01-03                 92     POINT(-79 28)     1  Wednesday
# 5 2018-01-03                119     POINT(-78 28)     1  Wednesday
# 6 2018-01-03                 35   POINT(-79.3 28)     1  Wednesday
# 7 2018-01-03                 60   POINT(-79.1 28)     1  Wednesday
# 8 2018-01-03                 41   POINT(-78.7 28)     1  Wednesday
# 9 2018-01-03                119   POINT(-78.6 28)     1  Wednesday

# %%
df_structuring[["weekday", "number_of_strikes"]].groupby(["weekday"]).mean().sort_values(by=["number_of_strikes"], ascending=False)
# Out:
#            number_of_strikes
# weekday
# Tuesday            13.813599
# Friday             13.349972
# Thursday           13.240594
# Wednesday          13.224568
# Monday             13.152804
# Saturday           12.732694
# Sunday             12.324717

# %%
weekday_order = ['Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday']

# %%
;
g = sns.boxplot(data=df_structuring,
            x='weekday',
            y='number_of_strikes',
            order=weekday_order,
            showfliers=False
            )
g.set_title('Lightning distribution per weekday (2018)');

# %%
df_structuring_2 = pd.read_csv("./eda_structuring_with_python_dataset2.csv")
df_structuring_2.head()
# Out:
#          date  number_of_strikes  center_point_geom
# 0  2016-01-04                 55  POINT(-83.2 21.1)
# 1  2016-01-04                 33  POINT(-83.1 21.1)
# 2  2016-01-05                 46  POINT(-77.5 22.1)
# 3  2016-01-05                 28  POINT(-76.8 22.3)
# 4  2016-01-05                 28    POINT(-77 22.1)

# %%
df_structuring_2["date"] = pd.to_datetime(df_structuring_2["date"])

# %%
df_structuring_2.sort_values(by=["date"], ascending=False).head(10)
# Out:
#               date  number_of_strikes  center_point_geom
# 3217895 2017-12-31                  1  POINT(-88.1 25.9)
# 3217933 2017-12-31                  1  POINT(-89.3 28.4)
# 3217935 2017-12-31                  1  POINT(-88.4 28.8)
# 3217936 2017-12-31                  1  POINT(-88.3 28.8)
# 3217937 2017-12-31                  1  POINT(-86.9 28.8)
# 3217938 2017-12-31                  1    POINT(-49.9 41)
# 3217939 2017-12-31                  1    POINT(-49.4 41)
# 3217940 2017-12-31                  1    POINT(-51.8 42)
# 3217941 2017-12-31                  1    POINT(-50.7 42)
# 3217942 2017-12-31                  1    POINT(-48.5 42)

# %%
union_structuring = pd.concat([df_structuring.drop(["weekday", "week"], axis=1), df_structuring_2], ignore_index=True)
union_structuring.head()
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)

# %%
union_structuring['year'] = union_structuring.date.dt.year
union_structuring['month'] = union_structuring.date.dt.month
union_structuring['month_txt'] = union_structuring.date.dt.month_name()
union_structuring.head()
# Out:
#         date  number_of_strikes center_point_geom  year  month month_txt
# 0 2018-01-03                194     POINT(-75 27)  2018      1   January
# 1 2018-01-03                 41   POINT(-78.4 29)  2018      1   January
# 2 2018-01-03                 33   POINT(-73.9 27)  2018      1   January
# 3 2018-01-03                 38   POINT(-73.8 27)  2018      1   January
# 4 2018-01-03                 92     POINT(-79 28)  2018      1   January

# %%
union_structuring[['year','number_of_strikes']].groupby(['year']).sum()
# Out:
#       number_of_strikes
# year
# 2016           41582229
# 2017           35095195
# 2018           44600989

# %%
lightning_by_month = union_structuring[["month_txt", 'year', "number_of_strikes"]].groupby(['month_txt','year']).sum(numeric_only=True).reset_index()

lightning_by_month.head()
# Out:
#   month_txt  year  number_of_strikes
# 0     April  2016            2636427
# 1     April  2017            3819075
# 2     April  2018            1524339
# 3    August  2016            7250442
# 4    August  2017            6021702

# %%
lightning_by_year = union_structuring.groupby(['year']).agg(
    year_strikes = pd.NamedAgg(column="number_of_strikes", aggfunc="sum")).reset_index()
lightning_by_year.head()
# Out:
#    year  year_strikes
# 0  2016      41582229
# 1  2017      35095195
# 2  2018      44600989

# %%
percentage_lightning = lightning_by_month.merge(lightning_by_year,on='year')
percentage_lightning.sort_values(by="year")
# Out:
#     month_txt  year  number_of_strikes  year_strikes
# 0       April  2016            2636427      41582229
# 27   November  2016             367853      41582229
# 21      March  2016            2057527      41582229
# 18       June  2016            6647930      41582229
# 15       July  2016           10661475      41582229
# 24        May  2016            5800500      41582229
# 30    October  2016            1285451      41582229
# 9    February  2016             312676      41582229
# 12    January  2016             313595      41582229
# 6    December  2016             316450      41582229
# 33  September  2016            3931903      41582229
# 3      August  2016            7250442      41582229
# 7    December  2017             294958      35095195
# 1       April  2017            3819075      35095195
# 22      March  2017            1161857      35095195
# 28   November  2017             440341      35095195
# 19       June  2017            4988897      35095195
# ...

# %%
percentage_lightning["percentage_lightning_per_month"] = (percentage_lightning["number_of_strikes"]/percentage_lightning["year_strikes"]*100)
percentage_lightning.head()
# Out:
#   month_txt  year  number_of_strikes  year_strikes  \
# 0     April  2016            2636427      41582229
# 1     April  2017            3819075      35095195
# 2     April  2018            1524339      44600989
# 3    August  2016            7250442      41582229
# 4    August  2017            6021702      35095195
#
#    percentage_lightning_per_month
# 0                        6.340273
# 1                       10.882045
# 2                        3.417725
# 3                       17.436396
# 4                       17.158195

# %%
plt.figure(figsize=(10,6));

month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

sns.barplot(
    data = percentage_lightning,
    x = 'month_txt',
    y = 'percentage_lightning_per_month',
    hue = 'year',
    order = month_order );
plt.xlabel("Month");
plt.ylabel("% of lightning strikes");
plt.title("% of lightning strikes each Month (2016-2018)");
