# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("home/jovyan/work/eda_using_basic_data_functions_in_python_dataset1.csv")
df.head(10)
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)
# 5  2018-01-03                119     POINT(-78 28)
# 6  2018-01-03                 35   POINT(-79.3 28)
# 7  2018-01-03                 60   POINT(-79.1 28)
# 8  2018-01-03                 41   POINT(-78.7 28)
# 9  2018-01-03                119   POINT(-78.6 28)

# %%
df["date"] = pd.to_datetime(df["date"])
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)
# 5 2018-01-03                119     POINT(-78 28)
# 6 2018-01-03                 35   POINT(-79.3 28)
# 7 2018-01-03                 60   POINT(-79.1 28)
# 8 2018-01-03                 41   POINT(-78.7 28)
# 9 2018-01-03                119   POINT(-78.6 28)

# %%
df.shape
# Out:
# (3401012, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401012 entries, 0 to 3401011
# Data columns (total 5 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   date               datetime64[ns]
#  1   number_of_strikes  int64
#  2   center_point_geom  object
#  3   month              int32
#  4   month_txt          object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(2)
# memory usage: 116.8+ MB

# %%
df['date']= pd.to_datetime(df['date'])

# %%
# Calculate days with most lightning strikes.
df.groupby(['date']).sum().sort_values('number_of_strikes', ascending=False).head(10)
# Out:
#             number_of_strikes  \
# date
# 2018-08-29            1070457
# 2018-08-17             969774
# 2018-08-28             917199
# 2018-08-27             824589
# 2018-08-30             802170
# 2018-08-19             786225
# 2018-08-18             741180
# 2018-08-16             734475
# 2018-08-31             723624
# 2018-08-15             673455
#
#                                             center_point_geom   month  \
# date
# 2018-08-29  POINT(-85.7 29.1)POINT(-85.6 29.1)POINT(-84.5 ...  222016
# 2018-08-17  POINT(-80.6 20.3)POINT(-80.5 20.3)POINT(-80.4 ...  231264
# 2018-08-28  POINT(-108.2 28)POINT(-108.1 28)POINT(-108 28)...  188136
# 2018-08-27  POINT(-109 24.8)POINT(-108 24.8)POINT(-88.1 24...  196128
# 2018-08-30  POINT(-75.7 19)POINT(-75.6 19)POINT(-78 20)POI...  166640
# 2018-08-19  POINT(-73 35)POINT(-103 35)POINT(-101 35)POINT...  199416
# 2018-08-18  POINT(-110.7 46)POINT(-104.9 46)POINT(-115.1 4...  195976
# 2018-08-16  POINT(-97 20)POINT(-77 20)POINT(-96.9 20)POINT...  211080
# 2018-08-31  POINT(-95.2 48.4)POINT(-96 48.1)POINT(-96.1 48...  187664
# 2018-08-15  POINT(-95.7 20)POINT(-95.6 20)POINT(-82 21)POI...  189888
#
#                                                     month_txt
# date
# 2018-08-29  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-17  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-28  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-27  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-30  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-19  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-18  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-16  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-31  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...
# 2018-08-15  AugAugAugAugAugAugAugAugAugAugAugAugAugAugAugA...

# %%
df["month"] = df["date"].dt.month
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom  month month_txt
# 0 2018-01-03                194     POINT(-75 27)      1       Jan
# 1 2018-01-03                 41   POINT(-78.4 29)      1       Jan
# 2 2018-01-03                 33   POINT(-73.9 27)      1       Jan
# 3 2018-01-03                 38   POINT(-73.8 27)      1       Jan
# 4 2018-01-03                 92     POINT(-79 28)      1       Jan
# 5 2018-01-03                119     POINT(-78 28)      1       Jan
# 6 2018-01-03                 35   POINT(-79.3 28)      1       Jan
# 7 2018-01-03                 60   POINT(-79.1 28)      1       Jan
# 8 2018-01-03                 41   POINT(-78.7 28)      1       Jan
# 9 2018-01-03                119   POINT(-78.6 28)      1       Jan

# %%
# Calculate total number of strikes per month
df.groupby(['month'])[['number_of_strikes']].sum().sort_values('number_of_strikes', ascending=False).head(12)
# Out:
#        number_of_strikes
# month
# 8               15525255
# 7                8320400
# 6                6445083
# 5                4166726
# 9                3018336
# 2                2071315
# 4                1524339
# 10               1093962
# 1                 860045
# 3                 854168
# 11                409263
# 12                312097

# %%
df["month_txt"] = df["date"].dt.month_name().str.slice(stop=3)
df.head(10)
# Out:
#         date  number_of_strikes center_point_geom  month month_txt
# 0 2018-01-03                194     POINT(-75 27)      1       Jan
# 1 2018-01-03                 41   POINT(-78.4 29)      1       Jan
# 2 2018-01-03                 33   POINT(-73.9 27)      1       Jan
# 3 2018-01-03                 38   POINT(-73.8 27)      1       Jan
# 4 2018-01-03                 92     POINT(-79 28)      1       Jan
# 5 2018-01-03                119     POINT(-78 28)      1       Jan
# 6 2018-01-03                 35   POINT(-79.3 28)      1       Jan
# 7 2018-01-03                 60   POINT(-79.1 28)      1       Jan
# 8 2018-01-03                 41   POINT(-78.7 28)      1       Jan
# 9 2018-01-03                119   POINT(-78.6 28)      1       Jan

# %%
df_by_month = df.groupby(["month", "month_txt"])[["number_of_strikes"]].sum().sort_values(by=["month"], ascending=True).head(12).reset_index()
df_by_month.head(10)
# Out:
#    month month_txt  number_of_strikes
# 0      1       Jan             860045
# 1      2       Feb            2071315
# 2      3       Mar             854168
# 3      4       Apr            1524339
# 4      5       May            4166726
# 5      6       Jun            6445083
# 6      7       Jul            8320400
# 7      8       Aug           15525255
# 8      9       Sep            3018336
# 9     10       Oct            1093962

# %%
plt.bar(x=df_by_month['month_txt'],height= df_by_month['number_of_strikes'], label="Number of strikes")
plt.plot()

plt.xlabel("Months(2018)")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes in 2018 by months")
plt.legend()
plt.show()
