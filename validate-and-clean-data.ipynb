# %% [markdown]
# ## step 1: imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
companies = pd.read_csv('Modified_Unicorn_Companies.csv')
companies.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          FinTech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Institutional Venture Partners, Sequoia Capita...

# %% [markdown]
# ## step 2: data cleaning

# %%
companies.dtypes
# Out:
# Company             object
# Valuation            int64
# Date Joined         object
# Industry            object
# City                object
# Country/Region      object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
# converting the 'object' dtype column to 'datetime'
companies["Date Joined"] = pd.to_datetime(companies["Date Joined"])

# %%
# adding a column called 'Years To Unicorn'
companies["Years To Unicorn"] = companies["Date Joined"].dt.year - companies["Year Founded"]

# %%
companies.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          FinTech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn
# 0  Sequoia Capital China, SIG Asia Investments, S...                 5
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...                10
# 2  Tiger Global Management, Sequoia Capital China...                10
# 3        Khosla Ventures, LowercaseCapital, capitalG                 4
# 4  Institutional Venture Partners, Sequoia Capita...                 6

# %% [markdown]
# #### input validation

# %% [markdown]
# ##### correcting bad data

# %%
companies["Years To Unicorn"].describe()
# Out:
# count    1074.000000
# mean        7.013035
# std         5.331842
# min        -3.000000
# 25%         4.000000
# 50%         6.000000
# 75%         9.000000
# max        98.000000
# Name: Years To Unicorn, dtype: float64

# %% [markdown]
# 'Years To Unicorn' cannot be negative.

# %%
companies[companies['Years To Unicorn'] < 0]
# Out:
#       Company  Valuation Date Joined                      Industry      City  \
# 527  InVision          2  2017-11-01  Internet software & services  New York
#
#     Country/Region      Continent  Year Founded Funding  \
# 527  United States  North America          2020   $349M
#
#                                       Select Investors  Years To Unicorn
# 527  FirstMark Capital, Tiger Global Management, IC...                -3

# %%
print(companies.loc[companies['Company']=='InVision', 'Year Founded'])
companies.loc[companies['Company']=='InVision', 'Year Founded'] = 2011
# an internet search reveals that InVision was founded in 2011
# Out:
# 527    2020
# Name: Year Founded, dtype: int64

# %%
companies[companies['Company']=='InVision']
# checking out again
# Out:
#       Company  Valuation Date Joined                      Industry      City  \
# 527  InVision          2  2017-11-01  Internet software & services  New York
#
#     Country/Region      Continent  Year Founded Funding  \
# 527  United States  North America          2011   $349M
#
#                                       Select Investors  Years To Unicorn
# 527  FirstMark Capital, Tiger Global Management, IC...                -3

# %%
# recalculating all the values for 'Years To Unicorn'
companies["Years To Unicorn"] = companies["Date Joined"].dt.year - companies["Year Founded"]

# checking the final result
companies.loc[companies['Company']=='InVision', 'Years To Unicorn']
# Out:
# 527    6
# Name: Years To Unicorn, dtype: int64

# %%
# a list of all the industry name that should be in the dataset. any labels in the `Industry` column that are not in `industry_list` are misspellings.

industry_list = ['Artificial intelligence', 'Other','E-commerce & direct-to-consumer', 'Fintech',
       'Internet software & services','Supply chain, logistics, & delivery', 'Consumer & retail',
       'Data management & analytics', 'Edtech', 'Health', 'Hardware','Auto & transportation',
        'Travel', 'Cybersecurity','Mobile & telecommunications']

# %%
# checking which values are in 'Industry' but not in industry_list.

# %%
# first way
set(companies['Industry']) - set(industry_list)
# Out:
# {'Artificial Intelligence', 'Data management and analytics', 'FinTech'}

# %%
# second way
mask = ~companies['Industry'].isin(industry_list)
companies[mask]["Industry"].unique()
# Out:
# array(['FinTech', 'Data management and analytics',
#        'Artificial Intelligence'], dtype=object)

# %%
## correcting the bad entries with 'replace()' method.

# companies["Industry"] = companies["Industry"].replace("Artificial Intelligence", "Artificial intelligence")
#
# companies["Industry"] = companies["Industry"].replace("Data management and analytics", "Data management & analytics")
#
# companies["Industry"] = companies["Industry"].replace("FinTech", "Fintech")


## a way simpler and way shorter way to do this operation:

replacement_dict = {
    "Artificial Intelligence" : "Artificial intelligence",
    "Data management and analytics" : "Data management & analytics",
    "FinTech" : "Fintech",
}

companies["Industry"] = companies["Industry"].replace(replacement_dict)

# %%
# checking if there are andy misspelling values still
set(companies['Industry']) - set(industry_list)
# Out:
# set()

# %%
companies[companies.duplicated(subset=['Company'], keep=False)]
# Out:
#          Company  Valuation Date Joined                 Industry         City  \
# 385      BrewDog          2  2017-04-10        Consumer & retail     Aberdeen
# 386      BrewDog          2  2017-04-10        Consumer & retail     Aberdeen
# 510       ZocDoc          2  2015-08-20                   Health     New York
# 511       ZocDoc          2  2015-08-20                   Health          NaN
# 1031  SoundHound          1  2018-05-03  Artificial intelligence  Santa Clara
# 1032  SoundHound          1  2018-05-03                    Other  Santa Clara
#
#       Country/Region      Continent  Year Founded Funding  \
# 385   United Kingdom         Europe          2007   $233M
# 386    UnitedKingdom         Europe          2007   $233M
# 510    United States  North America          2007   $374M
# 511    United States  North America          2007   $374M
# 1031   United States  North America          2005   $215M
# 1032   United States  North America          2005   $215M
#
#                                        Select Investors  Years To Unicorn
# 385                    TSG Consumer Partners, Crowdcube                10
# 386                               TSG Consumer Partners                10
# 510       Founders Fund, Khosla Ventures, Goldman Sachs                 8
# 511                                       Founders Fund                 8
# 1031  Tencent Holdings, Walden Venture Capital, Glob...                13
# 1032                                   Tencent Holdings                13

# %%
# dropping rows of duplicate companies after their first occurrence

companies = companies.drop_duplicates(subset=['Company'], keep="first")

# %% [markdown]
# ### convert numerical data into categorical data

# %%
companies["High Valuation"] = pd.qcut(
    companies["Valuation"],
    2,
    labels=["low", "high"],
)
companies.sample(10)
# Out:
#               Company  Valuation Date Joined                      Industry  \
# 714             Yotpo          1  2021-03-18  Internet software & services
# 374       Ximalaya FM          2  2017-09-22   Mobile & telecommunications
# 732         DistroKid          1  2021-08-16  Internet software & services
# 521  CoinSwitch Kuber          2  2021-10-06                       Fintech
# 559             Druva          2  2019-06-20   Data management & analytics
# 479            Reltio          2  2021-11-04   Data management & analytics
# 113  Cityblock Health          6  2020-12-10                        Health
# 302       Blockstream          3  2021-08-24                       Fintech
# 441              Clio          2  2021-04-27  Internet software & services
# 370            Pagaya          2  2020-06-17                       Fintech
#
#              City Country/Region      Continent  Year Founded  Funding  \
# 714      New York  United States  North America          2011    $436M
# 374      Shanghai          China           Asia          2012     $71M
# 732      New York  United States  North America          2013  Unknown
# 521     Bangalore          India           Asia          2017    $301M
# 559     Sunnyvale  United States  North America          2007    $475M
# 479  Redwood City  United States  North America          2011    $237M
# 113      Brooklyn  United States  North America          2017    $891M
# 302     Vancouver         Canada  North America          2014    $299M
# 441       Burnaby         Canada  North America          2008    $386M
# 370      Tel Aviv         Israel           Asia          2015    $417M
#
#                                       Select Investors  Years To Unicorn  \
# 714  Bessemer Venture Partners, Vintage Investment ...                10
# 374  China Creation Ventures, Sierra Ventures, Xing...                 5
# 732  Insight Partners, Silversmith Capital Partners...                 8
# 521  Tiger Global Management, Sequoia Capital India...                 4
# 559  Nexus Venture Partners, Tenaya Capital, Sequoi...                12
# 479  Crosslink Capital, .406 Ventures, Sapphire Ven...                10
# 113  Thrive Capital, Maverick Ventures, Redpoint Ve...                 3
# 302  AME Cloud Ventures, Future Perfect Ventures, B...                 7
# 441  OMERS Private Equity, T. Rowe Price, Technolog...                13
# 370  Oak HC/FT Partners, GF Investments, Harvey Gol...                 5
#
#     High Valuation
# 714            low
# 374            low
# 732            low
# 521            low
# 559            low
# 479            low
# 113           high
# 302           high
# 441            low
# 370            low

# %% [markdown]
# #### converting continent to numeric
#
# the investment group has specified that they want to give more weight to continents with fewer unicorn companies because they believe this could indicate unrealized market potential

# %%
companies.value_counts(["Continent"])
# Out:
# Continent
# North America    586
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: count, dtype: int64

# %%
continent_number_mapping = {
    "Africa" : 6,
    "Oceania" : 5,
    "South America" : 4,
    "Europe" : 3,
    "Asia" : 2,
    "North America" : 1,

}
companies["Continent Number"] = companies["Continent"].replace(continent_number_mapping)
# Out:
# /var/folders/t4/jpr0xd116_x6l353_cy_v6g80000gn/T/ipykernel_28591/865105549.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   companies["Continent Number"] = companies["Continent"].replace(continent_number_mapping)

# %%
companies.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn  \
# 0  Sequoia Capital China, SIG Asia Investments, S...                 5
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...                10
# 2  Tiger Global Management, Sequoia Capital China...                10
# 3        Khosla Ventures, LowercaseCapital, capitalG                 4
# 4  Institutional Venture Partners, Sequoia Capita...                 6
#
#   High Valuation  Continent Number
# 0           high                 5
# 1           high                 6
# 2           high                 5
# 3           high                 6
# 4           high                 4

# %%
companies["Country/Region Numeric"] = companies['Country/Region'].astype('category').cat.codes

# %%
companies["Country/Region Numeric"].head()
# Out:
# 0     9
# 1    44
# 2     9
# 3    44
# 4    38
# Name: Country/Region Numeric, dtype: int8

# %%
industry_encoded = pd.get_dummies(companies['Industry'])
companies = pd.concat([companies, industry_encoded], axis=1)
companies.head()
# Out:
#      Company  Valuation Date Joined                         Industry  \
# 0  Bytedance        180  2017-04-07          Artificial intelligence
# 1     SpaceX        100  2012-12-01                            Other
# 2      SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe         95  2014-01-23                          Fintech
# 4     Klarna         46  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Years To Unicorn  \
# 0  Sequoia Capital China, SIG Asia Investments, S...                 5
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...                10
# 2  Tiger Global Management, Sequoia Capital China...                10
# 3        Khosla Ventures, LowercaseCapital, capitalG                 4
# 4  Institutional Venture Partners, Sequoia Capita...                 6
#
#   High Valuation  Continent Number  Country/Region Numeric  \
# 0           high                 2                       9
# 1           high                 1                      44
# 2           high                 2                       9
# 3           high                 1                      44
# 4           high                 3                      38
#
#    Artificial intelligence  Auto & transportation  Consumer & retail  \
# 0                     True                  False              False
# 1                    False                  False              False
# 2                    False                  False              False
# 3                    False                  False              False
# 4                    False                  False              False
#
#    Cybersecurity  Data management & analytics  \
# 0          False                        False
# 1          False                        False
# 2          False                        False
# 3          False                        False
# 4          False                        False
#
#    E-commerce & direct-to-consumer  Edtech  Fintech  Hardware  Health  \
# 0                            False   False    False     False   False
# 1                            False   False    False     False   False
# 2                             True   False    False     False   False
# 3                            False   False     True     False   False
# 4                            False   False     True     False   False
#
#    Internet software & services  Mobile & telecommunications  Other  \
# 0                         False                        False  False
# 1                         False                        False   True
# 2                         False                        False  False
# 3                         False                        False  False
# 4                         False                        False  False
#
#    Supply chain, logistics, & delivery  Travel  Artificial intelligence  \
# 0                                False   False                     True
# 1                                False   False                    False
# 2                                False   False                    False
# 3                                False   False                    False
# 4                                False   False                    False
#
#    Auto & transportation  Consumer & retail  Cybersecurity  \
# 0                  False              False          False
# 1                  False              False          False
# 2                  False              False          False
# 3                  False              False          False
# 4                  False              False          False
#
#    Data management & analytics  E-commerce & direct-to-consumer  Edtech  \
# 0                        False                            False   False
# 1                        False                            False   False
# 2                        False                             True   False
# 3                        False                            False   False
# 4                        False                            False   False
#
#    Fintech  Hardware  Health  Internet software & services  \
# 0    False     False   False                         False
# 1    False     False   False                         False
# 2    False     False   False                         False
# 3     True     False   False                         False
# 4     True     False   False                         False
#
#    Mobile & telecommunications  Other  Supply chain, logistics, & delivery  \
# 0                        False  False                                False
# 1                        False   True                                False
# 2                        False  False                                False
# 3                        False  False                                False
# 4                        False  False                                False
#
#    Travel  Artificial intelligence  Auto & transportation  Consumer & retail  \
# 0   False                     True                  False              False
# 1   False                    False                  False              False
# 2   False                    False                  False              False
# 3   False                    False                  False              False
# 4   False                    False                  False              False
#
#    Cybersecurity  Data management & analytics  \
# 0          False                        False
# 1          False                        False
# 2          False                        False
# 3          False                        False
# 4          False                        False
#
#    E-commerce & direct-to-consumer  Edtech  Fintech  Hardware  Health  \
# 0                            False   False    False     False   False
# 1                            False   False    False     False   False
# 2                             True   False    False     False   False
# 3                            False   False     True     False   False
# 4                            False   False     True     False   False
#
#    Internet software & services  Mobile & telecommunications  Other  \
# 0                         False                        False  False
# 1                         False                        False   True
# 2                         False                        False  False
# 3                         False                        False  False
# 4                         False                        False  False
#
#    Supply chain, logistics, & delivery  Travel
# 0                                False   False
# 1                                False   False
# 2                                False   False
# 3                                False   False
# 4                                False   False
